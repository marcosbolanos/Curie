# %%
import pandas as pd

# %%
# This csv file is the output of the model we want to benchmark
# It contains our model's predictions, generated by an R script
model_predictions = pd.read_csv("inputs/24mai_Output_all_rds.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1565/1123440606.py in ?()
#       1 # This csv file is the output of the model we want to benchmark
#       2 # It contains our model's predictions, generated by an R script
#       3 model_predictions = pd.read_csv("inputs/24mai_Output_all_rds.csv")
# ----> 4 unique_mutants_list = model_predictions.groupy("mutant")["mutant"].to_list()
#
# /var/home/marcos/Code/bioinfo/Marcos/synlethdb-benchmark2/.venv/lib64/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'groupy'

# %%
unique_mutants_list = model_predictions["mutant"].unique()

# %%
str = ""
for mut in unique_mutants_list:
    str += (mut + ",\n")

with open("inputs/unique_mutants_tested.csv", "w") as f:
    f.write(str)
